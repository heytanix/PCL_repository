# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.1-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting numpy>=1.22.0 (from scikit-learn)
#   Downloading numpy-2.3.2-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Downloading scipy-1.16.1-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (61 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.7.1-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 692.6 kB/s eta 0:00:00a 0:00:01
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading numpy-2.3.2-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 499.6 kB/s eta 0:00:0000:0100:02
# Downloading scipy-1.16.1-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.2/35.2 MB 713.1 kB/s eta 0:00:0000:0100:02
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, numpy, joblib, scipy, scikit-learn
# Successfully installed joblib-1.5.2 numpy-2.3.2 scikit-learn-1.7.1 scipy-1.16.1 threadpoolctl-3.6.0

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

# %%
# Placeholder paths to replace
SOURCE_DIR = 'dataset_yolo/images/train/'  # Replace with the full path to your 'train' folder (containing non-violent and violent subfolders)
OUTPUT_DIR = 'cnn_set/images/'                           # Replace with the path where you want to save the split data (e.g., a new folder like cnn_splits)

# %%
# Classes (based on your structure)
CLASSES = ['non-violent', 'violent']  # Adjust if your folder names differ (note: use exact folder names)

# %%
# Split ratios (train + test should sum to 1.0; add validation if needed)
TRAIN_RATIO = 0.8  # 80% for training
TEST_RATIO = 0.2   # 20% for testing

# %%
# Function to split and copy images
def split_data(source_dir, output_dir, classes, train_ratio, test_ratio):
    for cls in classes:
        cls_dir = os.path.join(source_dir, cls)
        if not os.path.exists(cls_dir):
            print(f"Warning: Directory {cls_dir} does not exist. Skipping class '{cls}'.")
            continue
        
        # Get list of image files
        images = [f for f in os.listdir(cls_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
        if not images:
            print(f"Warning: No images found in {cls_dir}. Skipping class '{cls}'.")
            continue
        
        # Split the images
        train_imgs, test_imgs = train_test_split(images, test_size=test_ratio, random_state=42)
        
        # Copy to output directories
        for split, img_list in zip(['train', 'test'], [train_imgs, test_imgs]):
            dst_dir = os.path.join(output_dir, split, cls)
            os.makedirs(dst_dir, exist_ok=True)
            for img in img_list:
                src_path = os.path.join(cls_dir, img)
                dst_path = os.path.join(dst_dir, img)
                shutil.copy(src_path, dst_path)
    
    print(f'Data split complete! Train/Test ratio: {train_ratio}/{test_ratio}. Output saved to {output_dir}')

# Run the split
split_data(SOURCE_DIR, OUTPUT_DIR, CLASSES, TRAIN_RATIO, TEST_RATIO)
# Out:
# Data split complete! Train/Test ratio: 0.8/0.2. Output saved to cnn_set/images/
